# %%
import numpy as np
import random

# %%
arr1 = np.random.random((3,3))
arr1
# Out:
# array([[0.69496335, 0.52313518, 0.45325323],
#        [0.99881124, 0.31960675, 0.95986551],
#        [0.88818227, 0.67065736, 0.75750648]])

# %%
arr2 = np.random.randint(1,33,(3,3,3)) # GENERATE RANDOM INTEGER VALUE ARRAY
arr2
# Out:
# array([[[22, 19, 10],
#         [15,  8,  2],
#         [29, 18,  1]],
#
#        [[ 2,  8, 15],
#         [26, 17,  2],
#         [22, 28, 13]],
#
#        [[28, 24, 24],
#         [10, 32, 27],
#         [13,  7, 14]]])

# %%
arr3 = np.random.seed(10)
arr3
